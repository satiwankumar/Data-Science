# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x= [1,2,3,4,5,6,7]
y= [50,51,52,48,47,49,46]

# %%
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("TempatureByDay")
plt.plot(x,y,marker="+",color = "red",linewidth=5,linestyle='dotted')

# %%
plt.plot(x,y,'dg--',markersize=20,alpha=0.5)#shorcut order doesnot matter
