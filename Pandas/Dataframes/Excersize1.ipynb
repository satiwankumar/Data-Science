# %%
import pandas as pd

# %%
df=pd.read_csv('nyc_weather.csv')#pd.DataFrame('filename') also give us a data frame
df.head()#inital five rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()#tail() gives us last five rows
df.tail(1)#you can specify number of rows too
df[2:5]#your can also use Slicing in DataFrames
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.columns#will print number of columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
#df.Temperature df['Temperature'] both are same
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
#columns in the DataFrame are Pandas webseries
type(df['Temperature'])
# Out:
# pandas.core.series.Series

# %%
df[['Temperature','Humidity']] #to print only few columns
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()#to print maximum temperature
# Out:
# 50

# %%
df['Temperature'].min()#to print mininum temperature
# Out:
# 20

# %%
df['Temperature'].mean()
# Out:
# 34.67741935483871

# %%
df[['Temperature','Humidity']].describe()#to print complete anaylis of statistics
# Out:
#        Temperature   Humidity
# count    31.000000  31.000000
# mean     34.677419  51.677419
# std       7.639315  11.634395
# min      20.000000  33.000000
# 25%      29.000000  44.500000
# 50%      35.000000  50.000000
# 75%      39.500000  55.000000
# max      50.000000  78.000000

# %%
df[df['Temperature'] > 4 0]# to get all based on condition if Temperature >40
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
df.set_index('EST',inplace = True)

# %%
df.head()
# Out:
#           Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016           38        23        52                 30.03
# 1/2/2016           36        18        46                 30.02
# 1/3/2016           40        21        47                 29.86
# 1/4/2016           25         9        44                 30.05
# 1/5/2016           20        -3        41                 30.57
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 1/1/2016               10           8.0               0           5    NaN
# 1/2/2016               10           7.0               0           3    NaN
# 1/3/2016               10           8.0               0           1    NaN
# 1/4/2016               10           9.0               0           3    NaN
# 1/5/2016               10           5.0               0           0    NaN
#
#           WindDirDegrees
# EST
# 1/1/2016             281
# 1/2/2016             275
# 1/3/2016             277
# ...

# %%
#df.reset_index(inplace=True) to Reset index

# %%
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# ...

# %%
df.loc['1/11/2016']
# Out:
# Temperature                33
# DewPoint                    8
# Humidity                   37
# Sea Level PressureIn    29.92
# VisibilityMiles            10
# WindSpeedMPH              NaN
# PrecipitationIn             0
# CloudCover                  1
# Events                    NaN
# WindDirDegrees            289
# Name: 1/11/2016, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 0         0      0   1/1/2016           38        23        52
# 1         1      1   1/2/2016           36        18        46
# 2         2      2   1/3/2016           40        21        47
# 3         3      3   1/4/2016           25         9        44
# 4         4      4   1/5/2016           20        -3        41
# 5         5      5   1/6/2016           33         4        35
# 6         6      6   1/7/2016           39        11        33
# 7         7      7   1/8/2016           39        29        64
# 8         8      8   1/9/2016           44        38        77
# 9         9      9  1/10/2016           50        46        71
# 10       10     10  1/11/2016           33         8        37
# 11       11     11  1/12/2016           35        15        53
# 12       12     12  1/13/2016           26         4        42
# 13       13     13  1/14/2016           30        12        47
# ...

# %%
df
# Out:
#            level_0  index  Temperature  DewPoint  Humidity  \
# EST
# 1/1/2016         0      0           38        23        52
# 1/2/2016         1      1           36        18        46
# 1/3/2016         2      2           40        21        47
# 1/4/2016         3      3           25         9        44
# 1/5/2016         4      4           20        -3        41
# 1/6/2016         5      5           33         4        35
# 1/7/2016         6      6           39        11        33
# 1/8/2016         7      7           39        29        64
# 1/9/2016         8      8           44        38        77
# 1/10/2016        9      9           50        46        71
# 1/11/2016       10     10           33         8        37
# 1/12/2016       11     11           35        15        53
# 1/13/2016       12     12           26         4        42
# 1/14/2016       13     13           30        12        47
# 1/15/2016       14     14           43        31        62
# ...
